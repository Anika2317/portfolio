# %% [markdown]
# ---
# layout: post
# title: "CS111 Evidence: Control Structures"
# permalink: /cs111/control/
# ---

# %% [markdown]
# # CS111 Evidence: Control Structures
# This notebook contains the Control Structures evidence portfolio for CS111.
# Use this page to show loops, conditionals, and branching logic in working examples.
