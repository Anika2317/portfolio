# %% [markdown]
# ---
# layout: post
# title: "CS111 Evidence: Data Types"
# permalink: /cs111/data/
# ---

# %% [markdown]
# # CS111 Evidence: Data Types
# This notebook contains the Data Types evidence portfolio for CS111.
# Include examples for numbers, strings, booleans, arrays, and object-like structures.
