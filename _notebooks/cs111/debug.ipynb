# %% [markdown]
# ---
# layout: post
# title: "CS111 Evidence: Debugging"
# permalink: /cs111/debug/
# ---

# %% [markdown]
# # CS111 Evidence: Debugging
# This notebook contains the Debugging evidence portfolio for CS111.
# Show debugging techniques, error analysis, and step-by-step fixes.
