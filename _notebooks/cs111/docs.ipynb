# %% [markdown]
# ---
# layout: post
# title: "CS111 Evidence: Documentation"
# permalink: /cs111/docs/
# ---

# %% [markdown]
# # CS111 Evidence: Documentation
# This notebook contains the Documentation evidence portfolio for CS111.
# Demonstrate clear comments, function descriptions, and explanatory notes.
