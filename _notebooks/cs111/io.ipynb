# %% [markdown]
# ---
# layout: post
# title: "CS111 Evidence: Input/Output"
# permalink: /cs111/io/
# ---

# %% [markdown]
# # CS111 Evidence: Input/Output
# This notebook contains the Input/Output evidence portfolio for CS111.
# Include examples of reading and writing values, prompts, and output formatting.
