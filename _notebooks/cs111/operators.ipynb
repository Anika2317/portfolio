# %% [markdown]
# ---
# layout: post
# title: "CS111 Evidence: Operators"
# permalink: /cs111/operators/
# ---

# %% [markdown]
# # CS111 Evidence: Operators
# This notebook contains the Operators evidence portfolio for CS111.
# Show arithmetic, comparison, logical, and string operators with real examples.
