# %% [markdown]
# ---
# layout: post
# title: "CS111 Evidence: Testing & Verification"
# permalink: /cs111/testing/
# ---

# %% [markdown]
# # CS111 Evidence: Testing & Verification
# This notebook contains the Testing & Verification evidence portfolio for CS111.
# Show how code is verified, tested, and validated through examples.
