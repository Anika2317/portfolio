# %% [markdown]
# ---
# layout: post
# title: "3.10 Lists"
# categories: [Python]
# lesson_language: Python
# lesson_topic: Lists
# lesson_part: interactive
# lesson_type: lesson
# permalink: /csp/big-idea-3/lists/
# author: Anika2317
# toc: true
# comments: false
# ---
