# %% [raw]
# ---
# layout: post
# title: UESL 3.2 Homework
# author: anika2317
# permalink: /homework/3-2/
# ---

# %% [markdown]
# ## Popcorn
#
# **Prediction:** Before running, the list will become `[6, 12, 12, 5]` and the length will be `4`.
# **AP Index:** The AP index that selects the same second level as Python index 1 is AP index 2.
#
# ```python
# level_stars = [6, 9, 12]
# level_stars[1] = level_stars[1] + 3
# level_stars.append(5)
# print(level_stars)
# print(len(level_stars))
